# %%
# Logging
# Working with paths and directories

# %%
# What is logging?

# A->B->C

# 5 Seconds

# Timestamp A, Timestamp B, Timestamp C
# 100 ms, 4 second, 300 ms


# 500 errors, 400 errors ^

# %%
# "~/Desktop/Personal/Tom/Cat/file1final.txt"

import os
